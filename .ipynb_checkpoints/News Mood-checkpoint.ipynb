# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import tweepy
import time

from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from config import consumer_key, consumer_secret, access_token, access_token_secret

#Define SentimentIntensityAnalyzer function as variable for simplicity
analyzer = SentimentIntensityAnalyzer()

# %%
#Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser =tweepy.parsers.JSONParser())

# %%
#Create list of usernames for target news organizations
target_users = ["@BBCWorld", "@CBSNews", "@CNN", "@FoxNews", "@nytimes"]

# %%
#Create an empty DataFrame for desired lists of values
news_info = {"Screen Name" : [],
             "Tweet": [],
             "Date": [],
             "Compound Score": [],
             "Positive Score": [],
             "Negative Score": [],
             "Neutral Score": [], 
             "Tweets Ago": []}

pd.DataFrame(news_info, columns = ["Screen Name", "Tweet", "Date", "Compound Score",
                                   "Positive Score", "Negative Score", "Neutral Score",
                                   "Tweets Ago"])
# Out:
# Empty DataFrame
# Columns: [Screen Name, Tweet, Date, Compound Score, Positive Score, Negative Score, Neutral Score, Tweets Ago]
# Index: []

# %%
#Loop through each username in target_users
for username in target_users:
    
    #Keep track of tweet count
    tweet_count = 0
    
    #Loop through last 100 tweets (nested loop)
    for x in range(5):
        #Pull tweets from username's timeline
        public_tweets = api.user_timeline(username, page=x)
public_tweets
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:46:47 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979399482214318080',
#      'indices': [116, 139],
#      'url': 'https://t.co/XV3YduMu0f'}],
#    'user_mentions': []},
#   'favorite_count': 185,
#   'favorited': False,
#   'geo': None,
#   'id': 979399482214318080,
#   'id_str': '979399482214318080',
#   'in_reply_to_screen_name': 'nytimes',
#   'in_reply_to_status_id': 979399051669114881,
#   'in_reply_to_status_id_str': '979399051669114881',
#   'in_reply_to_user_id': 807095,
#   'in_reply_to_user_id_str': '807095',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 90,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'The shooting has reignited the kind of protests against police killings that spread over the past several years in… https://t.co/XV3YduMu0f',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:45:04 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979399051669114881',
#      'indices': [117, 140],
#      'url': 'https://t.co/GeIH1cZwdE'}],
#    'user_mentions': []},
#   'favorite_count': 634,
#   'favorited': False,
#   'geo': None,
#   'id': 979399051669114881,
#   'id_str': '979399051669114881',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 431,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': '“A lot of white people are truly shocked by what these videos depict; I know very few African-Americans who are sur… https://t.co/GeIH1cZwdE',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:37:32 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979397155134803968',
#      'indices': [117, 140],
#      'url': 'https://t.co/0c7UVCIEkE'}],
#    'user_mentions': []},
#   'favorite_count': 244,
#   'favorited': False,
#   'geo': None,
#   'id': 979397155134803968,
#   'id_str': '979397155134803968',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 299,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'At least 68 people died in a fire in a Venezuelan jail. The authorities fired tear gas and rubber bullets at grievi… https://t.co/0c7UVCIEkE',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:30:15 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'nyti.ms/2GhItRY',
#      'expanded_url': 'https://nyti.ms/2GhItRY',
#      'indices': [111, 134],
#      'url': 'https://t.co/dsU9QuANDN'}],
#    'user_mentions': []},
#   'favorite_count': 302,
#   'favorited': False,
#   'geo': None,
#   'id': 979395320705667073,
#   'id_str': '979395320705667073',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 208,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'How a 16-year-old girl named Yu Gwan-sun became the face of Korea’s struggle for freedom in the spring of 1919 https://t.co/dsU9QuANDN',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:23:06 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979393523140235264',
#      'indices': [117, 140],
#      'url': 'https://t.co/Wlu56Y3Pwf'}],
#    'user_mentions': []},
#   'favorite_count': 1362,
#   'favorited': False,
#   'geo': None,
#   'id': 979393523140235264,
#   'id_str': '979393523140235264',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 397,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': "Eric Holder says he'll sue the Trump administration to block it from adding a question about citizenship to the 202… https://t.co/Wlu56Y3Pwf",
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:17:15 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 336020675,
#      'id_str': '336020675',
#      'indices': [3, 18],
#      'name': 'Stephen Castle',
#      'screen_name': '_StephenCastle'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 979392050473955328,
#   'id_str': '979392050473955328',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 27,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 29 15:51:44 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'nyti.ms/2GlIOms',
#       'expanded_url': 'https://nyti.ms/2GlIOms',
#       'indices': [110, 133],
#       'url': 'https://t.co/NstLZBRjq6'}],
#     'user_mentions': []},
#    'favorite_count': 25,
#    'favorited': False,
#    'geo': None,
#    'id': 979385629762113537,
#    'id_str': '979385629762113537',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 27,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "“More conspicuous, more commonplace and more corrosive” - the anti-Semitism afflicting Britain's Labour Party https://t.co/NstLZBRjq6",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 15 16:31:43 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Correspondent in London bureau of New York Times, formerly IHT bureau chief in Brussels',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 67,
#     'follow_request_sent': False,
#     'followers_count': 3858,
#     'following': False,
#     'friends_count': 1672,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 336020675,
#     'id_str': '336020675',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 158,
#     'location': '',
#     'name': 'Stephen Castle',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/336020675/1425488617',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/716616854991671296/pzbXxR9V_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/716616854991671296/pzbXxR9V_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': '_StephenCastle',
#     'statuses_count': 1736,
#     'time_zone': 'Amsterdam',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 7200,
#     'verified': True}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "RT @_StephenCastle: “More conspicuous, more commonplace and more corrosive” - the anti-Semitism afflicting Britain's Labour Party https://t…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:15:08 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1754641,
#      'id_str': '1754641',
#      'indices': [3, 19],
#      'name': 'NYT Business',
#      'screen_name': 'nytimesbusiness'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 979391515830181890,
#   'id_str': '979391515830181890',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 31,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 29 11:30:06 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979319786525032448',
#       'indices': [117, 140],
#       'url': 'https://t.co/Vi5cl5v5ql'}],
#     'user_mentions': []},
#    'favorite_count': 37,
#    'favorited': False,
#    'geo': None,
#    'id': 979319786525032448,
#    'id_str': '979319786525032448',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 31,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': 'Outside the United States, social media is fueling real-world violence and empowering autocrats, often with much le… https://t.co/Vi5cl5v5ql',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Mar 21 14:49:39 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Financial, tech, media and other business news from The New York Times.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nytimes.com/business',
#         'expanded_url': 'http://nytimes.com/business',
#         'indices': [0, 22],
#         'url': 'http://t.co/OKrfdBy4ch'}]}},
#     'favourites_count': 896,
#     'follow_request_sent': False,
#     'followers_count': 796070,
#     'following': False,
#     'friends_count': 389,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1754641,
#     'id_str': '1754641',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 14350,
#     'location': 'New York, NY',
#     'name': 'NYT Business',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/4433659/twitter_post.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/4433659/twitter_post.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1754641/1518629416',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/963826250895654912/P-W5YvhN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963826250895654912/P-W5YvhN_normal.jpg',
#     'profile_link_color': '004276',
#     'profile_sidebar_border_color': '323232',
#     'profile_sidebar_fill_color': 'E7EFF8',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nytimesbusiness',
#     'statuses_count': 175605,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/OKrfdBy4ch',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'RT @nytimesbusiness: Outside the United States, social media is fueling real-world violence and empowering autocrats, often with much less…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 16:00:28 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979387828005203969',
#      'indices': [117, 140],
#      'url': 'https://t.co/IFezlRJ7pR'}],
#    'user_mentions': []},
#   'favorite_count': 112,
#   'favorited': False,
#   'geo': None,
#   'id': 979387828005203969,
#   'id_str': '979387828005203969',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 71,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'According to a lawsuit filed by a criminal defense lawyer, a judge told him that he spent too much time defending i… https://t.co/IFezlRJ7pR',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 15:57:28 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 86640232,
#      'id_str': '86640232',
#      'indices': [3, 15],
#      'name': 'NYT Graphics',
#      'screen_name': 'nytgraphics'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 979387069192654848,
#   'id_str': '979387069192654848',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 12,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 29 15:30:01 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979380164931895296',
#       'indices': [117, 140],
#       'url': 'https://t.co/rfBR8B1iPL'}],
#     'user_mentions': []},
#    'favorite_count': 20,
#    'favorited': False,
#    'geo': None,
#    'id': 979380164931895296,
#    'id_str': '979380164931895296',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 12,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'People often point to Beirut when they talk about design in the Middle East. “Beirut is saturated,” counter the fou… https://t.co/rfBR8B1iPL',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Nov 01 01:48:22 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The New York Times Graphics Department',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nytimes.com',
#         'expanded_url': 'http://www.nytimes.com/',
#         'indices': [0, 22],
#         'url': 'http://t.co/RWXhcxY5rv'}]}},
#     'favourites_count': 70,
#     'follow_request_sent': False,
#     'followers_count': 135539,
#     'following': False,
#     'friends_count': 65,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 86640232,
#     'id_str': '86640232',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 4441,
#     'location': 'New York, NY',
#     'name': 'NYT Graphics',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/56059603/twitter_post.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/56059603/twitter_post.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/86640232/1506726555',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/964525048353775616/InmWAWbL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964525048353775616/InmWAWbL_normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nytgraphics',
#     'statuses_count': 4933,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/RWXhcxY5rv',
#     'utc_offset': -14400,
#     'verified': True}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @nytgraphics: People often point to Beirut when they talk about design in the Middle East. “Beirut is saturated,” counter the founders o…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 15:54:59 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1754641,
#      'id_str': '1754641',
#      'indices': [3, 19],
#      'name': 'NYT Business',
#      'screen_name': 'nytimesbusiness'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 979386447370309634,
#   'id_str': '979386447370309634',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 18,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 29 15:25:03 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979378914647838721',
#       'indices': [117, 140],
#       'url': 'https://t.co/40wKydokec'}],
#     'user_mentions': []},
#    'favorite_count': 32,
#    'favorited': False,
#    'geo': None,
#    'id': 979378914647838721,
#    'id_str': '979378914647838721',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': 'How a racist hoodie made its way through the design, production and marketing process without being caught, and how… https://t.co/40wKydokec',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Mar 21 14:49:39 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Financial, tech, media and other business news from The New York Times.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nytimes.com/business',
#         'expanded_url': 'http://nytimes.com/business',
#         'indices': [0, 22],
#         'url': 'http://t.co/OKrfdBy4ch'}]}},
#     'favourites_count': 896,
#     'follow_request_sent': False,
#     'followers_count': 796070,
#     'following': False,
#     'friends_count': 389,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1754641,
#     'id_str': '1754641',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 14350,
#     'location': 'New York, NY',
#     'name': 'NYT Business',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/4433659/twitter_post.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/4433659/twitter_post.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1754641/1518629416',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/963826250895654912/P-W5YvhN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/963826250895654912/P-W5YvhN_normal.jpg',
#     'profile_link_color': '004276',
#     'profile_sidebar_border_color': '323232',
#     'profile_sidebar_fill_color': 'E7EFF8',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nytimesbusiness',
#     'statuses_count': 175605,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/OKrfdBy4ch',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @nytimesbusiness: How a racist hoodie made its way through the design, production and marketing process without being caught, and how co…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 15:52:04 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979385712805105664',
#      'indices': [116, 139],
#      'url': 'https://t.co/e2NUHSlGOM'}],
#    'user_mentions': []},
#   'favorite_count': 154,
#   'favorited': False,
#   'geo': None,
#   'id': 979385712805105664,
#   'id_str': '979385712805105664',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 53,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'At 26, the Cuban artist Belkis Ayón was invited to show at the Venice Biennale in Italy. But first, she had to get… https://t.co/e2NUHSlGOM',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
# ...
#      'expanded_url': 'https://twitter.com/i/web/status/979368869453234181',
#      'indices': [117, 140],
#      'url': 'https://t.co/TmWSzHRB74'}],
#    'user_mentions': []},
#   'favorite_count': 125,
#   'favorited': False,
#   'geo': None,
#   'id': 979368869453234181,
#   'id_str': '979368869453234181',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 71,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': '"The business that she\'s in — I\'m sorry," said Debbie Lesko, a Republican candidate for Congress, about Stormy Dani… https://t.co/TmWSzHRB74',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 14:30:04 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1440641,
#      'id_str': '1440641',
#      'indices': [3, 15],
#      'name': 'New York Times Arts',
#      'screen_name': 'nytimesarts'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 979365076430917638,
#   'id_str': '979365076430917638',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 30,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Mar 29 13:12:17 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979345501161246720',
#       'indices': [117, 140],
#       'url': 'https://t.co/cKUD0lkBDy'}],
#     'user_mentions': []},
#    'favorite_count': 68,
#    'favorited': False,
#    'geo': None,
#    'id': 979345501161246720,
#    'id_str': '979345501161246720',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 30,
#    'retweeted': False,
#    'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#    'text': '"I had all the fame and the money and everything that went with it, but I started realizing what was important to m… https://t.co/cKUD0lkBDy',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Mar 18 20:30:33 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Arts and entertainment news from The New York Times.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'nytimes.com/arts',
#         'expanded_url': 'http://www.nytimes.com/arts',
#         'indices': [0, 22],
#         'url': 'http://t.co/0H74AaBX8Y'}]}},
#     'favourites_count': 301,
#     'follow_request_sent': False,
#     'followers_count': 2643693,
#     'following': False,
#     'friends_count': 226,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1440641,
#     'id_str': '1440641',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 19388,
#     'location': 'New York, NY',
#     'name': 'New York Times Arts',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/2800588/twitter.post.gif',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/2800588/twitter.post.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1440641/1510847448',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/964180969702895616/wJcdJ1MU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964180969702895616/wJcdJ1MU_normal.jpg',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '323232',
#     'profile_sidebar_fill_color': 'E7EFF8',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'nytimesarts',
#     'statuses_count': 141399,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/0H74AaBX8Y',
#     'utc_offset': -14400,
#     'verified': True}},
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'RT @nytimesarts: "I had all the fame and the money and everything that went with it, but I started realizing what was important to me was m…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 14:21:06 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#      'expanded_url': 'https://twitter.com/i/web/status/979362820889464832',
#      'indices': [117, 140],
#      'url': 'https://t.co/reV37SloPb'}],
#    'user_mentions': []},
#   'favorite_count': 109,
#   'favorited': False,
#   'geo': None,
#   'id': 979362820889464832,
#   'id_str': '979362820889464832',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 85,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'To secure trade agreements quickly, the White House has taken a contentious approach to negotiations not seen in de… https://t.co/reV37SloPb',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 29 14:11:06 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'nyti.ms/2IZbcJ3',
#      'expanded_url': 'https://nyti.ms/2IZbcJ3',
#      'indices': [117, 140],
#      'url': 'https://t.co/Tcjj8dj7GK'}],
#    'user_mentions': []},
#   'favorite_count': 277,
#   'favorited': False,
#   'geo': None,
#   'id': 979360304017674240,
#   'id_str': '979360304017674240',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 116,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'Rusty Staub, a fan favorite for the New York Mets who played in the majors for more than two decades, has died at 73 https://t.co/Tcjj8dj7GK',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 02 20:41:42 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.',
#    'entities': {'description': {'urls': [{'display_url': 'nyti.ms/2FVHq9v',
#        'expanded_url': 'http://nyti.ms/2FVHq9v',
#        'indices': [113, 136],
#        'url': 'https://t.co/ghL9OoYKMM'}]},
#     'url': {'urls': [{'display_url': 'nytimes.com',
#        'expanded_url': 'http://www.nytimes.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/ahvuWqicF9'}]}},
#    'favourites_count': 16550,
#    'follow_request_sent': False,
#    'followers_count': 41592144,
#    'following': False,
#    'friends_count': 879,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 807095,
#    'id_str': '807095',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 195108,
#    'location': 'New York City',
#    'name': 'The New York Times',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/736339684/948f072cc2da4e3a5e9f2ebfb3b1a0e7.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1522172276',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942784892882112513/qV4xB0I3_normal.jpg',
#    'profile_link_color': '607696',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nytimes',
#    'statuses_count': 314651,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'http://t.co/ahvuWqicF9',
#    'utc_offset': -14400,
#    'verified': True}}]
